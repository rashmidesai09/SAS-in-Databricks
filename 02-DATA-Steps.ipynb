# %% [markdown]
# d
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/wiki-book/general/logo_spark_tiny.png) Performing SAS DATA Step operations in Databricks
#
#
# **In this lesson you:**
# - Learn how to perform some of the most common DATA Step operations in Databricks
# - Demonstrate examples of performing DATA steps using PySpark and Spark SQL
# - Become familiar with looking up functions in Databricks and Apache Spark documentation

# %% [markdown]
# NOTE:
# Many of the most commonly used operations are covered in more depth in the Databricks Academy course "Introduction to Apache Spark Programming with Databricks".
#
# Other recommended courses include "Introduction to SQL on Databricks", "Applications of SQL on Databricks", and "Just Enough Python for Apache Spark".

# %% [markdown]
# SAS DATA steps are generally used to:
#   - read input files
#   - work with variables and numbers
#   - merge datasets (unions and joins)
#
# In the previous lesson, we used `spark.read` to read in files, without altering the variables. Now, we will demonstrate how to perform some of other common operations in Databricks.
#
# NOTE: Any of the SAS Data Steps you are used to performing can be translated directly into Spark SQL.

# %% [markdown]
# Run the following cell to get started:

# %%
# %run ./Includes/classroom-setup-2
# Out:
# username: rashbeats@gmail.com
# working_dir:   dbfs:/user/rashbeats_gmail_com/dbacademy/sasproc
# database_name: dbacademy_rashbeats_gmail_com_sasproc
# Out[1]: True
# Out[2]: True

# %% [markdown]
# ## Setting up the data

# %% [markdown]
# In this lesson, we will be working with some global sales data. The data files have already been copied from a source directory in cloud storage to your dbfs location, `filepath`.

# %%
dbutils.fs.ls(filepath)
# Out:
# Out[3]: [FileInfo(path='dbfs:/dbfs/user/rashbeats_gmail_com/dbacademy/sasproc/rawdata/cities/', name='cities/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/dbfs/user/rashbeats_gmail_com/dbacademy/sasproc/rawdata/retailers/', name='retailers/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/dbfs/user/rashbeats_gmail_com/dbacademy/sasproc/rawdata/transactions/', name='transactions/', size=0, modificationTime=0)]

# %%
# Python trick! You can also use a Python list comprehension with dbutils to list all the items in the filepath
[print(item) for item in dbutils.fs.ls(filepath)]
# Out:
# FileInfo(path='dbfs:/dbfs/user/rashbeats_gmail_com/dbacademy/sasproc/rawdata/cities/', name='cities/', size=0, modificationTime=0)
# FileInfo(path='dbfs:/dbfs/user/rashbeats_gmail_com/dbacademy/sasproc/rawdata/retailers/', name='retailers/', size=0, modificationTime=0)
# FileInfo(path='dbfs:/dbfs/user/rashbeats_gmail_com/dbacademy/sasproc/rawdata/transactions/', name='transactions/', size=0, modificationTime=0)
# Out[4]: [None, None, None]

# %%
# read each of the raw data files into a DataFrame
cities_df = spark.read.format("delta").load(filepath + '/cities')
retailers_df = spark.read.format("delta").load(filepath + '/retailers')
transactions_df = spark.read.format("delta").load(filepath + '/transactions')

# %% [markdown]
# You can view the schema of a DataFrame to see the data types of each variable:

# %%
cities_df.printSchema()
# Out:
# root
#  |-- city_id: integer (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- state_abv: string (nullable = true)
#  |-- country: string (nullable = true)

# %% [markdown]
# As you saw in the previous notebook, creating temp tables from the DataFrames will allow you to query them using Spark SQL.
#
# NOTE: Recall that these tables will not persist after your current Spark session, meaning that they will not be available if you restart the cluster or switch to a new notebook.

# %%
retailers_df.createOrReplaceTempView("retailers")
transactions_df.createOrReplaceTempView("transactions")
cities_df.createOrReplaceTempView("cities")

# %% [markdown]
# ## Performing DATA Steps
#
# There are many references in the official documentation for how to perform these operations using PySpark or Spark SQL:
#
# [PySpark DataFrame functions](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.DataFrame.html#pyspark-sql-dataframe)
# [SQL built-in functions](https://docs.databricks.com/spark/latest/spark-sql/language-manual/sql-ref-functions-builtin.html)
#
# We will demonstrate some of the operations you may be used to performing, and how you do these in Databricks, in the rest of this notebook.

# %% [markdown]
# ### 1. Merge
#
# In SAS, a Merge operation might look like:
#
# ```
# data retailers_df;
#  merge transactions_df;
#  by retailer_id;
# run;
# ```
#
# In this example, we will merge `retailers_df` and `transactions_df` on the `retailer_id` field, first using PySpark, then using Spark SQL, using the [`join` function](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.DataFrame.join.html#pyspark.sql.DataFrame.join).
#
# NOTE: With Spark, you do NOT have to sort datasets before performing operations on them!

# %%
# with PySpark
sales_df = (retailers_df.join(transactions_df, "retailer_id"))
display(sales_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>retailer_id</th><th>retailer</th><th>us_sales</th><th>other_sales</th><th>all_sales</th><th>us_vs_world</th><th>city_id</th><th>amount</th><th>trx_id</th><th>description</th><th>transacted_at</th></tr></thead><tbody><tr><td>847200066</td><td>Wal-Mart</td><td>343624000</td><td>164841000</td><td>508465000</td><td>0.6758065943575271</td><td>28424447</td><td>46.11</td><td>1249734743</td><td>Wal-Mart   ccd id: 428530</td><td>2011-11-25 19:00:00</td></tr><tr><td>1076023740</td><td>Aldi</td><td>11728000</td><td>41794000</td><td>53522000</td><td>0.2191248458577781</td><td>1518631622</td><td>251.86</td><td>1249734744</td><td>unkn     ppd id: 680848    Bern    11-25</td><td>2011-11-25 19:00:00</td></tr><tr><td>847200066</td><td>Wal-Mart</td><td>343624000</td><td>164841000</td><td>508465000</td><td>0.6758065943575271</td><td>1601875893</td><td>31.89</td><td>1249734745</td><td>Wal-Mart     ppd id: 813297</td><td>2011-11-25 19:00:00</td></tr><tr><td>902350112</td><td>DineEquity</td><td>7137000</td><td>452000</td><td>7589000</td><td>0.94044011068652</td><td>1217211842</td><td>92.96</td><td>1249734746</td><td>DineEquity  ppd id: 379557</td><td>2011-11-25 19:00:00</td></tr><tr><td>1445595477</td><td>Meijer</td><td>15689000</td><td>0</td><td>15689000</td><td>1.0</td><td>1898204901</td><td>309.37</td><td>1249734747</td><td>Meijer   arc id: 773946     Dar es Salaam  11-26</td><td>2011-11-25 19:00:00</td></tr><tr><td>1953761884</td><td>Home Depot</td><td>74203000</td><td>8992000</td><td>83195000</td><td>0.891916581525332</td><td>1137214313</td><td>38.66</td><td>1249734748</td><td>unkn    arc id: 624310  Buenos Aires</td><td>2011-11-25 19:00:00</td></tr><tr><td>1273066548</td><td>7-Eleven</td><td>11390000</td><td>76635000</td><td>88025000</td><td>0.129395058222096</td><td>2055198208</td><td>1543.66</td><td>1249734749</td><td>7-Eleven    ccd id: 226597  Bismarck</td><td>2011-11-25 19:00:00</td></tr><tr><td>1318092070</td><td>Bi-Lo</td><td>10362000</td><td>0</td><td>10362000</td><td>1.0</td><td>275328977</td><td>383.93</td><td>1249734750</td><td>Bi-Lo   ppd id: 1004833     11-27</td><td>2011-11-25 19:00:00</td></tr><tr><td>847200066</td><td>Wal-Mart</td><td>343624000</td><td>164841000</td><td>508465000</td><td>0.6758065943575271</td><td>1359730291</td><td>28.12</td><td>1249734751</td><td>Wal-Mart     ccd id: 1029496</td><td>2011-11-25 19:00:00</td></tr><tr><td>9225731</td><td>AT&T Wireless</td><td>12960000</td><td>0</td><td>12960000</td><td>1.0</td><td>407629665</td><td>1145.21</td><td>1249734752</td><td>unkn         Kingston   11-27</td><td>2011-11-25 19:00:00</td></tr><tr><td>1768219832</td><td>Macy's</td><td>28027000</td><td>78000</td><td>28105000</td><td>0.9972246931151041</td><td>810296651</td><td>23.33</td><td>87071448</td><td>Macy's    arc id: 218570   Tallahassee  11-27</td><td>2011-11-25 19:00:00</td></tr><tr><td>2001148981</td><td>Costco</td><td>79694000</td><td>31836000</td><td>111530000</td><td>0.7145521384380884</td><td>1676567417</td><td>69.15</td><td>87071449</td><td>Costco    Richmond</td><td>2011-11-25 19:00:00</td></tr><tr><td>847200066</td><td>Wal-Mart</td><td>343624000</td><td>164841000</td><td>508465000</td><td>0.6758065943575271</td><td>2096878759</td><td>70.69</td><td>87071450</td><td>Wal-Mart     ccd id: 130121</td><td>2011-11-25 19:00:00</td></tr><tr><td>2129689717</td><td>Wegmans Food Market</td><td>7405000</td><td>0</td><td>7405000</td><td>1.0</td><td>1722006496</td><td>12.37</td><td>87071451</td><td>Wegmans Food Market   ppd id: 962660</td><td>2011-11-25 19:00:00</td></tr><tr><td>1314985216</td><td>A&P</td><td>5630000</td><td>0</td><td>5630000</td><td>1.0</td><td>218089872</td><td>41.33</td><td>87071452</td><td>A&P    ccd id: 514043  11-26</td><td>2011-11-25 19:00:00</td></tr><tr><td>1126742091</td><td>H-E-B Grocery</td><td>19819000</td><td>1347000</td><td>21166000</td><td>0.93636020032127</td><td>8311243 ...

# %% [markdown]
# ### 2. Working with dates
#
# `DATE`
# To return the current date like you would do with the SAS `today()` function, use the [function `current_date`](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.functions.current_date.html).
#
# `TODAY`
# If you have a date in the number of seconds from unix epoch (1970-01-01 00:00:00 UTC) format, you can convert it to a string representing the datetime in a specified timezone using the [`from_unixtime` function](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.functions.from_unixtime.html).
#
# `YEAR`
# To extract the year from a date as an integer, like with the SAS `year()` function, use the [`year` function](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.functions.year.html).

# %% [markdown]
# Create a column "year" by extracting the year from the "transacted_at" field:

# %%
# in PySpark:
from pyspark.sql.functions import year
display(transactions_df.select(year('transacted_at').alias('year')))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th></tr></thead><tbody><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><tr><td>2011</td></tr><t ...

# %% [markdown]
# Extract various date formats from a datetime column using `date_format` and create new columns using `withColumn`:

# %%
import pyspark.sql.functions as F

from pyspark.sql.functions import date_format

formattedDF = (transactions_df.withColumn("date string", date_format("transacted_at", "MMMM dd, yyyy"))
  .withColumn("time string", date_format("transacted_at", "HH:mm:ss.SSSSSS"))
)
display(formattedDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city_id</th><th>amount</th><th>retailer_id</th><th>trx_id</th><th>description</th><th>transacted_at</th><th>date string</th><th>time string</th></tr></thead><tbody><tr><td>28424447</td><td>46.11</td><td>847200066</td><td>1249734743</td><td>Wal-Mart   ccd id: 428530</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>1518631622</td><td>251.86</td><td>1076023740</td><td>1249734744</td><td>unkn     ppd id: 680848    Bern    11-25</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>1601875893</td><td>31.89</td><td>847200066</td><td>1249734745</td><td>Wal-Mart     ppd id: 813297</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>1217211842</td><td>92.96</td><td>902350112</td><td>1249734746</td><td>DineEquity  ppd id: 379557</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>1898204901</td><td>309.37</td><td>1445595477</td><td>1249734747</td><td>Meijer   arc id: 773946     Dar es Salaam  11-26</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>1137214313</td><td>38.66</td><td>1953761884</td><td>1249734748</td><td>unkn    arc id: 624310  Buenos Aires</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>2055198208</td><td>1543.66</td><td>1273066548</td><td>1249734749</td><td>7-Eleven    ccd id: 226597  Bismarck</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>275328977</td><td>383.93</td><td>1318092070</td><td>1249734750</td><td>Bi-Lo   ppd id: 1004833     11-27</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>1359730291</td><td>28.12</td><td>847200066</td><td>1249734751</td><td>Wal-Mart     ccd id: 1029496</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>407629665</td><td>1145.21</td><td>9225731</td><td>1249734752</td><td>unkn         Kingston   11-27</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>810296651</td><td>23.33</td><td>1768219832</td><td>87071448</td><td>Macy's    arc id: 218570   Tallahassee  11-27</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>1676567417</td><td>69.15</td><td>2001148981</td><td>87071449</td><td>Costco    Richmond</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>2096878759</td><td>70.69</td><td>847200066</td><td>87071450</td><td>Wal-Mart     ccd id: 130121</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>1722006496</td><td>12.37</td><td>2129689717</td><td>87071451</td><td>Wegmans Food Market   ppd id: 962660</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>218089872</td><td>41.33</td><td>1314985216</td><td>87071452</td><td>A&P    ccd id: 514043  11-26</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>831124332</td><td>79.0</td><td>1126742091</td><td>87071453</td><td>H-E-B Grocery    ppd id: 820329  Austin</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>45522086</td><td>21.12</td><td>400404203</td><td>87071454</td><td>CVS  ppd id: 485827    Little Rock</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>216510442</td><td>2361.40</td><td>847200066</td><td>87071455</td><td>Wal-Mart    ccd id: 420609  Kuala Lumpur</td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td><td>19:00:00.000000</td></tr><tr><td>45522086</td><td>197.78</td><td>887300947</td><td>87071456</td><td>Kroger    </td><td>2011-11-25 19:00:00</td><td>November 25, 2011</td> ...

# %% [markdown]
# There are many, many other ways to work with dates in PySpark and Spark SQL. See the official [Databricks documentation](https://docs.databricks.com/spark/latest/dataframes-datasets/dates-timestamps.html) for more!

# %% [markdown]
# ### 3. Working with strings

# %% [markdown]
# To extract a substring from a string, as in the SAS function `substr()`, use the [`substring` function](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.functions.substring.html).
#
# You can use the [`trim` function](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.functions.trim.html) in PySpark to perform the same functions as `strip()` in SAS.

# %%
from pyspark.sql.functions import substring
display(transactions_df.select('description', substring(trim('description'), 1,8).alias('desc_short')))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>description</th><th>desc_short</th></tr></thead><tbody><tr><td>Wal-Mart   ccd id: 428530</td><td>Wal-Mart</td></tr><tr><td>unkn     ppd id: 680848    Bern    11-25</td><td>unkn    </td></tr><tr><td>Wal-Mart     ppd id: 813297</td><td>Wal-Mart</td></tr><tr><td>DineEquity  ppd id: 379557</td><td>DineEqui</td></tr><tr><td>Meijer   arc id: 773946     Dar es Salaam  11-26</td><td>Meijer  </td></tr><tr><td>unkn    arc id: 624310  Buenos Aires</td><td>unkn    </td></tr><tr><td>7-Eleven    ccd id: 226597  Bismarck</td><td>7-Eleven</td></tr><tr><td>Bi-Lo   ppd id: 1004833     11-27</td><td>Bi-Lo   </td></tr><tr><td>Wal-Mart     ccd id: 1029496</td><td>Wal-Mart</td></tr><tr><td>unkn         Kingston   11-27</td><td>unkn    </td></tr><tr><td>Macy's    arc id: 218570   Tallahassee  11-27</td><td>Macy's  </td></tr><tr><td>Costco    Richmond</td><td>Costco  </td></tr><tr><td>Wal-Mart     ccd id: 130121</td><td>Wal-Mart</td></tr><tr><td>Wegmans Food Market   ppd id: 962660</td><td>Wegmans </td></tr><tr><td>A&P    ccd id: 514043  11-26</td><td>A&P    c</td></tr><tr><td>H-E-B Grocery    ppd id: 820329  Austin</td><td>H-E-B Gr</td></tr><tr><td>CVS  ppd id: 485827    Little Rock</td><td>CVS  ppd</td></tr><tr><td>Wal-Mart    ccd id: 420609  Kuala Lumpur</td><td>Wal-Mart</td></tr><tr><td>Kroger    </td><td>Kroger</td></tr><tr><td>unkn         Dili</td><td>unkn    </td></tr><tr><td>McDonald's         Quito</td><td>McDonald</td></tr><tr><td>SUPERVALU  ccd id: 978529  Tunis  11-27</td><td>SUPERVAL</td></tr><tr><td>unkn   ccd id: 531253  Olympia</td><td>unkn   c</td></tr><tr><td>Target       11-27</td><td>Target  </td></tr><tr><td>Publix Super Markets   </td><td>Publix S</td></tr><tr><td>Macy's    arc id: 363274   Augusta  11-27</td><td>Macy's  </td></tr><tr><td>Safeway       San Jose    11-27</td><td>Safeway </td></tr><tr><td>Stater Bros    ppd id: 1078402  11-26</td><td>Stater B</td></tr><tr><td>unkn    ppd id: 956833</td><td>unkn    </td></tr><tr><td>iTunes    ccd id: 283510</td><td>iTunes  </td></tr><tr><td>Costco  arc id: 407052  Lincoln</td><td>Costco  </td></tr><tr><td>L Brands    ppd id: 540157    11-25</td><td>L Brands</td></tr><tr><td>Wal-Mart     ccd id: 755303  11-27</td><td>Wal-Mart</td></tr><tr><td>PetSmart   arc id: 574252</td><td>PetSmart</td></tr><tr><td>unkn    ccd id: 371478  Olympia</td><td>unkn    </td></tr><tr><td>Ahold          Olympia     11-26</td><td>Ahold   </td></tr><tr><td>unkn  arc id: 936050</td><td>unkn  ar</td></tr><tr><td>Walgreen     ppd id: 290766     Praia</td><td>Walgreen</td></tr><tr><td>unkn   ppd id: 581397   Kigali</td><td>unkn   p</td></tr><tr><td>CVS    arc id: 983674</td><td>CVS    a</td></tr><tr><td>Wal-Mart    ppd id: 307436    Little Rock</td><td>Wal-Mart</td></tr><tr><td>Home Depot  ppd id: 466298</td><td>Home Dep</td></tr><tr><td>unkn    ppd id: 770540</td><td>unkn    </td></tr><tr><td>Dick's Sporting Goods     </td><td>Dick's S</td></tr><tr><td>Wal-Mart   ccd id: 1017350   Ankara</td><td>Wal-Mart</td></tr><tr><td>Wal-Mart     ppd id: 154441</td><td>Wal-Mart</td></tr><tr><td>YUM! Brands    ccd id: 581194   Abuja</td><td>YUM! Bra</td></tr><tr><td>Chick-fil-A    ccd id: 670424     Jackson  11-27</td><td>Chick-fi</td></tr><tr><td>Kroger    arc id: 212647  Maseru   11-25</td><td>Kroger  </td></tr><tr><td>Dunkin' Donuts  ccd id: 840736   Prague</td><td>Dunkin' </td></tr><tr><td>DineEquity          New Delhi</td><td>DineEqui</td></tr><tr><td>YUM! Brands    ppd id: 220050    Rome    11-25</td><td>YUM! Bra</td></tr><tr><td>unkn     arc id: 712773    Cairo</td><td>unkn    </td></tr><tr><td>Kroger     ppd id: 512093    Boston</td><td>Kroger  </td></tr><tr><td>unkn  ppd id: 942514     11-26</td><td>unkn  pp</td></tr><tr><td>Domino's Pizza  arc id: 1078456   11-26</td><td>Domino's</td></tr><tr><td>unkn     ppd id: 1069630     Sao Tome</td><td>unkn    </td></tr><tr><td>Rite Aid    ccd id: 215014    ...

# %% [markdown]
# Like the other DATA Steps, you can perform the same action as the SAS `lowcase()` function using `LOWER()` in SQL or [PySpark](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.functions.lower.html):

# %%
# another way to do the same thing:
display(spark.sql("SELECT *, LOWER(description) AS desc_lower FROM transactions"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city_id</th><th>amount</th><th>retailer_id</th><th>trx_id</th><th>description</th><th>transacted_at</th><th>desc_lower</th></tr></thead><tbody><tr><td>28424447</td><td>46.11</td><td>847200066</td><td>1249734743</td><td>Wal-Mart   ccd id: 428530</td><td>2011-11-25 19:00:00</td><td>wal-mart   ccd id: 428530</td></tr><tr><td>1518631622</td><td>251.86</td><td>1076023740</td><td>1249734744</td><td>unkn     ppd id: 680848    Bern    11-25</td><td>2011-11-25 19:00:00</td><td>unkn     ppd id: 680848    bern    11-25</td></tr><tr><td>1601875893</td><td>31.89</td><td>847200066</td><td>1249734745</td><td>Wal-Mart     ppd id: 813297</td><td>2011-11-25 19:00:00</td><td>wal-mart     ppd id: 813297</td></tr><tr><td>1217211842</td><td>92.96</td><td>902350112</td><td>1249734746</td><td>DineEquity  ppd id: 379557</td><td>2011-11-25 19:00:00</td><td>dineequity  ppd id: 379557</td></tr><tr><td>1898204901</td><td>309.37</td><td>1445595477</td><td>1249734747</td><td>Meijer   arc id: 773946     Dar es Salaam  11-26</td><td>2011-11-25 19:00:00</td><td>meijer   arc id: 773946     dar es salaam  11-26</td></tr><tr><td>1137214313</td><td>38.66</td><td>1953761884</td><td>1249734748</td><td>unkn    arc id: 624310  Buenos Aires</td><td>2011-11-25 19:00:00</td><td>unkn    arc id: 624310  buenos aires</td></tr><tr><td>2055198208</td><td>1543.66</td><td>1273066548</td><td>1249734749</td><td>7-Eleven    ccd id: 226597  Bismarck</td><td>2011-11-25 19:00:00</td><td>7-eleven    ccd id: 226597  bismarck</td></tr><tr><td>275328977</td><td>383.93</td><td>1318092070</td><td>1249734750</td><td>Bi-Lo   ppd id: 1004833     11-27</td><td>2011-11-25 19:00:00</td><td>bi-lo   ppd id: 1004833     11-27</td></tr><tr><td>1359730291</td><td>28.12</td><td>847200066</td><td>1249734751</td><td>Wal-Mart     ccd id: 1029496</td><td>2011-11-25 19:00:00</td><td>wal-mart     ccd id: 1029496</td></tr><tr><td>407629665</td><td>1145.21</td><td>9225731</td><td>1249734752</td><td>unkn         Kingston   11-27</td><td>2011-11-25 19:00:00</td><td>unkn         kingston   11-27</td></tr><tr><td>810296651</td><td>23.33</td><td>1768219832</td><td>87071448</td><td>Macy's    arc id: 218570   Tallahassee  11-27</td><td>2011-11-25 19:00:00</td><td>macy's    arc id: 218570   tallahassee  11-27</td></tr><tr><td>1676567417</td><td>69.15</td><td>2001148981</td><td>87071449</td><td>Costco    Richmond</td><td>2011-11-25 19:00:00</td><td>costco    richmond</td></tr><tr><td>2096878759</td><td>70.69</td><td>847200066</td><td>87071450</td><td>Wal-Mart     ccd id: 130121</td><td>2011-11-25 19:00:00</td><td>wal-mart     ccd id: 130121</td></tr><tr><td>1722006496</td><td>12.37</td><td>2129689717</td><td>87071451</td><td>Wegmans Food Market   ppd id: 962660</td><td>2011-11-25 19:00:00</td><td>wegmans food market   ppd id: 962660</td></tr><tr><td>218089872</td><td>41.33</td><td>1314985216</td><td>87071452</td><td>A&P    ccd id: 514043  11-26</td><td>2011-11-25 19:00:00</td><td>a&p    ccd id: 514043  11-26</td></tr><tr><td>831124332</td><td>79.0</td><td>1126742091</td><td>87071453</td><td>H-E-B Grocery    ppd id: 820329  Austin</td><td>2011-11-25 19:00:00</td><td>h-e-b grocery    ppd id: 820329  austin</td></tr><tr><td>45522086</td><td>21.12</td><td>400404203</td><td>87071454</td><td>CVS  ppd id: 485827    Little Rock</td><td>2011-11-25 19:00:00</td><td>cvs  ppd id: 485827    little rock</td></tr><tr><td>216510442</td><td>2361.40</td><td>847200066</td><td>87071455</td><td>Wal-Mart    ccd id: 420609  Kuala Lumpur</td><td>2011-11-25 19:00:00</td><td>wal-mart    ccd id: 420609  kuala lumpur</td></tr><tr><td>45522086</td><td>197.78</td><td>887300947</td><td>87071456</td><td>Kroger    </td><td>2011-11-25 19:00:00</td><td>kroger    </td></tr><tr><td>448377372</td><td>460.80</td><td>847200066</td><td>87071457</td><td>unkn         Dili</td><td>2011-11-25 19:00:00</td><td>unkn         dili</td></tr><tr><td>1 ...

# %% [markdown]
# ## 4. Working with columns

# %% [markdown]
# In SAS, you use `IF/THEN/ELSE` and `WHERE` to create columns based on business logic.
#
# In this example, we will add a new column "volume" to `retailers_df` with the value "large" if "all_sales" is greater than 30000000, otherwise "small", using the PySpark functions `withColumn`[(docs link)](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.DataFrame.withColumn.html), `when` [(docs link)](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.Column.when.html), `otherwise` [(docs link)](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.Column.otherwise.html), and `col` [(docs link)](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.functions.col.html).

# %%
retailers_df = retailers_df.withColumn("volume", when(col("all_sales") > 30000000, "large").otherwise("small"))

display(retailers_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
829599844</td><td>large</td></tr><tr><td>2139149619</td><td>Trader Joe's</td><td>9388000</td><td>28218000</td><td>37606000</td><td>0.24964101473169176</td><td>large</td></tr><tr><td>1334799521</td><td>TJ Max</td><td>22206000</td><td>6855000</td><td>29061000</td><td>0.7641168576442655</td><td>small</td></tr><tr><td>354400420</td><td>Subway</td><td>13389000</td><td>10966000</td><td>24355000</td><td>0.5497433791829193</td><td>small</td></tr><tr><td>2120842315</td><td>Burger King</td><td>8517000</td><td>8593000</td><td>17110000</td><td>0.4977790765634132</td><td>small</td></tr><tr><td>562903918</td><td>McDonald's</td><td>35447000</td><td>52339000</td><td>87786000</td><td>0.4037887590276354</td><td>large</td></tr><tr><td>400404203</td><td>CVS</td><td>67974000</td><td>1158000</td> ...

# %% [markdown]
# ## 5. Working with data types
# `INPUT` and `PUT` convert a character value into a numeric value or vice versa, in SAS. The PySpark [`cast` function](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.sql.Column.cast.html) achieves the same.
#
# You can read more about data types in Spark in the [docs](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql.html#data-types).

# %%
# display the current data types
transactions_df.printSchema()
# Out:
# root
#  |-- city_id: string (nullable = true)
#  |-- amount: string (nullable = true)
#  |-- retailer_id: string (nullable = true)
#  |-- trx_id: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- transacted_at: string (nullable = true)

# %%
# cast the `city_id` column to integer type
transactions_df.withColumn('city_id', transactions_df.city_id.cast('int')).printSchema()
# Out:
# root
#  |-- city_id: integer (nullable = true)
#  |-- amount: string (nullable = true)
#  |-- retailer_id: string (nullable = true)
#  |-- trx_id: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- transacted_at: string (nullable = true)

# %%
# cast the `city_id` column back to string type
transactions_df.withColumn('city_id', transactions_df.city_id.cast('string')).printSchema()
# Out:
# root
#  |-- city_id: string (nullable = true)
#  |-- amount: string (nullable = true)
#  |-- retailer_id: string (nullable = true)
#  |-- trx_id: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- transacted_at: string (nullable = true)

# %% [markdown]
# ## 6. Working with numbers
#
# All of the mathematical functions you use in SAS, such as:
# - `CEIL`
# - `INT`
# - `ROUND`
# - `MEAN`, `MIN`, `MAX`
#
# can be performed using PySpark or SQL functions. Check out [the documentation](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql.html#functions) to see more!

# %% [markdown]
# Many mathematical operations are performed on aggregated objects. In Databricks, use the DataFrame `groupBy` method to create a grouped data object.
#
# Next, group `sales_df` by "city_id" and count the number of sales for each city:

# %%
sales_by_city_df = sales_df.groupBy("city_id").count()
display(sales_by_city_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city_id</th><th>count</th></tr></thead><tbody><tr><td>1126623009</td><td>97589</td></tr><tr><td>1744912105</td><td>97436</td></tr><tr><td>1607451095</td><td>287093</td></tr><tr><td>2008587661</td><td>97587</td></tr><tr><td>1932789846</td><td>97628</td></tr><tr><td>1985376021</td><td>287163</td></tr><tr><td>353140025</td><td>97297</td></tr><tr><td>1518631622</td><td>97580</td></tr><tr><td>2008300608</td><td>97256</td></tr><tr><td>1545959797</td><td>97570</td></tr><tr><td>31398417</td><td>97029</td></tr><tr><td>1646415505</td><td>97524</td></tr><tr><td>819842978</td><td>97893</td></tr><tr><td>197271663</td><td>287390</td></tr><tr><td>2078628066</td><td>97619</td></tr><tr><td>781290085</td><td>287564</td
# %% [markdown]
# Next, get the average amount per sale for each retailer.
#
# NOTE: We need to cast the data type of the "amount" column from a string to a number before we can perform aggregations on it.

# %%
sales_df = sales_df.withColumn("amount", sales_df.amount.cast('int'))

sales_by_retailer_df = sales_df.groupBy("retailer").avg("amount")
display(sales_by_retailer_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>retailer</th><th>avg(amount)</th></tr></thead><tbody><tr><td>Alimentation Couche-Tard</td><td>368.476730477741</td></tr><tr><td>GameStop</td><td>372.70613352310636</td></tr><tr><td>Michael's</td><td>373.65415659562</td></tr><tr><td>SUPERVALU</td><td>370.7857261734644</td></tr><tr><td>Nordstrom</td><td>370.7883616625341</td></tr><tr><td>QVC</td><td>372.9475708265569</td></tr><tr><td>Walgreen</td><td>369.6818027308248</td></tr><tr><td>Verizon Wireless</td><td>367.4953726077711</td></tr><tr><td>Dick's Sporting Goods</td><td>373.4431811584386</td></tr><tr><td>Gap</td><td>369.9919673947452</td></tr><tr><td>Costco</td><td>369.37996872947394</td></tr><tr><td>Trader Joe's</td><td>369.1437610802797</td></tr><tr><td>Albertsons</td><td>367.5378335426216</td></tr><tr><td>Subway</td><td>370.90393078738094</td></tr><tr><td>Hy-Vee</td><td>366.89067612687813</td></tr><tr><td>Defense Commissary Agency</td><td>369.35223400227187</td></tr><tr><td>WinCo Foods</td><td>373.4759554014211</td></tr><tr><td>J.C. Penney</td><td>368.67627711078785</td></tr><tr><td>Dollar Tree</td><td>369.0493536741586</td></tr><tr><td>Family Dollar Stores</td><td>370.30447631135274</td></tr><tr><td>Sears</td><td>368.36314437602243</td></tr><tr><td>Jack in the Box</td><td>366.0988488694744</td></tr><tr><td>Signet Jewelers</td><td>366.8020001835031</td></tr><tr><td>Giant Eagle</td><td>368.15119520786635</td></tr><tr><td>Publix Super Markets</td><td>369.217947773802</td></tr><tr><td>Dell</td><td>373.69680959847295</td></tr><tr><td>7-Eleven</td><td>368.3753638988391</td></tr><tr><td>Kroger</td><td>369.70888247774985</td></tr><tr><td>AutoZone</td><td>369.28124406608015</td></tr><tr><td>Chipotle Mexican Grill</td><td>372.2913515344052</td></tr><tr><td>Office Depot</td><td>371.4541413343152</td></tr><tr><td>Save Mart Supermarkets</td><td>369.7161033797217</td></tr><tr><td>Aldi</td><td>367.951331290184</td></tr><tr><td>Burlington Coat Factory</td><td>370.6863054655192</td></tr><tr><td>Safeway</td><td>370.1905505348496</td></tr><tr><td>O'Reilly</td><td>368.4288514379923</td></tr><tr><td>Foot Locker</td><td>371.2362315767151</td></tr><tr><td>Wal-Mart</td><td>369.21438230139984</td></tr><tr><td>Hudson's Bay</td><td>372.2978891260152</td></tr><tr><td>Bi-Lo</td><td>371.8473691598923</td></tr><tr><td>Darden Restaurants</td><td>370.84791285107826</td></tr><tr><td>WakeFern / ShopRite</td><td>371.54872358067814</td></tr><tr><td>Advance Auto Parts</td><td>371.06052215785115</td></tr><tr><td>Stater Bros</td><td>376.908202230029</td></tr><tr><td>Amazon.com</td><td>369.50718952166415</td></tr><tr><td>Dillard's</td><td>365.1731908029078</td></tr><tr><td>L Brands</td><td>369.0298748285642</td></tr><tr><td>TJ Max</td><td>368.7706531364554</td></tr><tr><td>Ross</td><td>368.78597845408666</td></tr><tr><td>Wegmans Food Market</td><td>369.84053067164245</td></tr><tr><td>Burger King</td><td>371.3258703141873</td></tr><tr><td>DineEquity</td><td>371.16831326170046</td></tr><tr><td>Menard</td><td>368.9312208887227</td></tr><tr><td>H-E-B Grocery</td><td>370.9317960491948</td></tr><tr><td>BJ's</td><td>371.1151269698075</td></tr><tr><td>Panera</td><td>370.3012623627787</td></tr><tr><td>Ascena Retail Group</td><td>370.95410066199645</td></tr><tr><td>Delhaize America</td><td>369.5022953149941</td></tr><tr><td>Williams-Sonoma</td><td>367.04862059158137</td></tr><tr><td>iTunes</td><td>367.9722308642936</td></tr><tr><td>Ahold</td><td>371.0966073863166</td></tr><tr><td>Barnes & Noble</td><td>368.46649455093785</td></tr><tr><td>Belk</td><td>376.20503203374005</td></tr><tr><td>Chick-fil-A</td><td>365.5729420808128</td></tr><tr><td>Home Depot</td><td>369.3646931623608</td></tr><tr><td>McDonald's</td><td>369.0934581142822</td></tr><tr><td>Rite Aid</td><td>371.07237261305033</td></tr><tr><td>Best Buy</td><td>371.24749248039666</td></tr><tr><td>Ace Hardware</td><td>368.072436187608</td></tr><tr><td>M ...

# %% [markdown]
# You can use the grouped data method `agg` to apply built-in aggregate functions.
#
# This allows you to apply other transformations on the resulting columns, such as `alias`.
#
# We can also use the `round` function to round the average amount.

# %%
sales_by_city_df = sales_df.groupBy("city_id").agg(round(avg("amount")).alias("avg_sale"))

display(sales_by_city_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city_id</th><th>avg_sale</th></tr></thead><tbody><tr><td>1126623009</td><td>370.0</td></tr><tr><td>1744912105</td><td>370.0</td></tr><tr><td>1607451095</td><td>370.0</td></tr><tr><td>2008587661</td><td>367.0</td></tr><tr><td>1932789846</td><td>366.0</td></tr><tr><td>1985376021</td><td>371.0</td></tr><tr><td>353140025</td><td>370.0</td></tr><tr><td>1518631622</td><td>373.0</td></tr><tr><td>2008300608</td><td>370.0</td></tr><tr><td>1545959797</td><td>365.0</td></tr><tr><td>31398417</td><td>368.0</td></tr><tr><td>1646415505</td><td>369.0</td></tr><tr><td>819842978</td><td>371.0</td></tr><tr><td>197271663</td><td>370.0</td></tr><tr><td>2078628066</td><td>365.0</td></tr><tr><td>781290085</td><td>368.0</td></tr><tr><td>1681951424</td><td>371.0</td></tr><tr><td>1098014353</td><td>367.0</td></tr><tr><td>1610115143</td><td>363.0</td></tr><tr><td>1722610684</td><td>373.0</td></tr><tr><td>627640221</td><td>371.0</td></tr><tr><td>720701459</td><td>372.0</td></tr><tr><td>763797543</td><td>367.0</td></tr><tr><td>810296651</td><td>368.0</td></tr><tr><td>668870263</td><td>373.0</td></tr><tr><td>1943510285</td><td>368.0</td></tr><tr><td>985710